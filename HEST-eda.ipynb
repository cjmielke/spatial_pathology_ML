# %%
import pandas as pd

# %%
pip install huggingface_hub
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 402.6/402.6 kB 8.8 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
meta_df = pd.read_csv("hf://datasets/MahmoodLab/hest/HEST_v1_0_0.csv")
meta_df
# Out:
#                                           dataset_title       id  \
# 0     FFPE Human Ovarian Cancer Data with Human Immu...  TENX142
# 1     FFPE Human Lung Cancer Data with Human Immuno-...  TENX141
# 2     FFPE Human Pancreatic Ductal Adenocarcinoma Da...  TENX140
# 3     FFPE Human Colorectal Cancer Data with Human I...  TENX139
# 4     FFPE Human Brain Cancer Data with Human Immuno...  TENX138
# ...                                                 ...      ...
# 1103                                        spatialLIBD    MISC5
# 1104                                        spatialLIBD    MISC4
# 1105                                        spatialLIBD    MISC3
# 1106                                        spatialLIBD    MISC2
# 1107                                        spatialLIBD    MISC1
#
#      image_filename     organ disease_state oncotree_code       species  \
# 0       TENX142.tif     Ovary        Cancer         HGSOC  Homo sapiens
# ...

# %%
meta_df.st_technology.value_counts()
# Out:
# st_technology
# Spatial Transcriptomics    552
# Visium                     515
# Xenium                      38
# Visium HD                    3
# Name: count, dtype: int64

# %%
meta_df[meta_df.st_technology=='Visium HD'].T
# Out:
#                                                                         11  \
# dataset_title            Visium HD Spatial Gene Expression Library, Mou...
# id                                                                 TENX131
# image_filename                                                 TENX131.tif
# organ                                                                Brain
# disease_state                                                      Healthy
# oncotree_code                                                          NaN
# species                                                       Mus musculus
# patient                                                                NaN
# st_technology                                                    Visium HD
# data_publication_date                                           2024-03-29
# license                                       Creative Commons Attribution
# ...

# %%
meta_df.tissue.value_counts().head(30)
# Out:
# tissue
# Spinal cord                       318
# Brain                             146
# Breast                            125
# Skin                               79
# Kidney                             42
# Prostate                           33
# Lymph node                         29
# Liver                              29
# prostate                           28
# Heart                              25
# Placenta                           23
# brain                              21
# Olfactory bulb                     16
# Colon                              13
# dorsolateral prefrontal cortex     12
# lung                               11
# Bronchi                            10
# Hippocampus                         9
# Lung                                9
# ileum                               8
# Hindlimb muscle                     7
# Pancreas                            7
# Parenchyma                          7
# bone                                6
# ...

# %%
meta_df[meta_df.tissue=='Bladder'].T
# Out:
#                                                                        400  \
# dataset_title            Batf3-dendritic cells and 4-1BB-4-1BB ligand a...
# id                                                                 NCBI855
# image_filename                                                 NCBI855.tif
# organ                                                              Bladder
# disease_state                                                       Cancer
# oncotree_code                                                         BLCA
# species                                                       Homo sapiens
# patient                                                         Patient 10
# st_technology                                                       Visium
# data_publication_date                                         May 13, 2024
# license                                                       CC BY-NC 4.0
# ...

# %%
meta_df[meta_df.tissue=='Lung'].T
# Out:
#                                                                        1    \
# dataset_title            FFPE Human Lung Cancer Data with Human Immuno-...
# id                                                                 TENX141
# image_filename                                                 TENX141.tif
# organ                                                                 Lung
# disease_state                                                       Cancer
# oncotree_code                                                         LUAD
# species                                                       Homo sapiens
# patient                                                          patient 1
# st_technology                                                       Xenium
# data_publication_date                                           2024-05-15
# license                                       Creative Commons Attribution
# ...
